# %% [markdown]
# <a href="https://colab.research.google.com/github/THANISHKAREDDYYANDAPU/fmml_project_and_labs_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 16:24:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   335MB/s    in 0.2s
#
# 2024-03-25 16:24:18 (335 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5406    1308.6342v4  We introduce a new embarrassingly parallel par...  stat
# 30122  1711.07399v1  Most of the existing deep learning-based metho...    cs
# 22708  1705.03536v2  A semi-parametric, non-linear regression model...  stat
# 22948  1711.07561v1  This is a technical report which explores the ...  stat
# 20830  1703.05204v2  Pairwise comparisons are an important tool of ...    cs
# ...             ...                                                ...   ...
# 9009   1611.05010v1  In topic modeling, many algorithms that guaran...  stat
# 3250   1612.05086v2  Mini-batch stochastic gradient descent and var...    cs
# 19521  cs/0612057v1  This is the second part of a paper on Consciou...    cs
# 13176  1711.05869v1  Testing (conditional) independence of multivar...  stat
# 22538  1611.00555v1  Kernel dependence measures yield accurate esti...  stat
#
#                                                    title  year  \
# 5406   Linear and Parallel Learning of Markov Random ...  2013
# 30122  V2V-PoseNet: Voxel-to-Voxel Prediction Network...  2017
# 22708        SILVar: Single Index Latent Variable Models  2017
# 22948             Review on Parameter Estimation in HMRF  2017
# 20830  On Inconsistency Indices and Inconsistency Axi...  2017
# ...                                                  ...   ...
# 9009   Anchor-Free Correlated Topic Modeling: Identif...  2016
# 3250   Coupling Adaptive Batch Sizes with Learning Rates  2016
# 19521  Conscious Intelligent Systems - Part II - Mind...  2006
# 13176  Predictive Independence Testing, Predictive Co...  2017
# 22538  Sensitivity Maps of the Hilbert-Schmidt Indepe...  2016
#
#                                                 keywords
# 5406   [introduce, embarrassingly, parameter, algorit...
# 30122  [estimation, framework, regresses, coordinates...
# 22708  [parametric, regression, variables, introduced...
# 22948  [technical, estimation, methodologies, paramet...
# 20830  [comparisons, important, judgments, inconsiste...
# ...                                                  ...
# 9009   [algorithms, guarantee, identifiability, devel...
# 3250   [stochastic, empirical, minimization, empirica...
# 19521  [conscious, intelligent, understanding, intell...
# 13176  [independence, multivariate, variables, statis...
# 22538  [dependence, estimates, nonlinear, relations, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5406     [introduce, embarrassingly, parameter, algorit...
# 30122    [estimation, framework, regresses, coordinates...
# 22708    [parametric, regression, variables, introduced...
# 22948    [technical, estimation, methodologies, paramet...
# 20830    [comparisons, important, judgments, inconsiste...
#                                ...
# 21853    [rendering, algorithms, emphasize, aesthetic, ...
# 14679    [representing, dictionaries, particular, accor...
# 24934    [contaminated, processing, suggested, intellig...
# 31399    [particles, microscopic, physicians, evaluatin...
# 2813     [processes, distributions, functions, generali...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8848 words.
# Out of those 4593 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16ce7963-62ee-46d0-a492-85f64d4ea12f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ce7963-62ee-46d0-a492-85f64d4ea12f")) {                    Plotly.newPlot(                        "16ce7963-62ee-46d0-a492-85f64d4ea12f",                        [{"x":["naturally","algorithm","statistics","introduce","embarrassingly","requiring","practical","complexity","competitors","sufficient","parameters","parameter","parallelizes","efficient","available","procedure","challenge","regresses","likelihood","projection","prediction","convolutional","distortion","intrinsically","keypoints","framework","coordinates","estimation","invariant","regressing","outperforms","weaknesses","conventional","difficulty","perspective","estimates","phenomena","regularized","contributions","presented","component","exhibited","correspond","demonstrate","established","paradigms","optimization","interactions","particular","formulation","particularly","regression","unmeasured","principal","introduced","networked","relations","performance","justified","experiments","simulated","linearities","parametric","structured","variables","theoretical","methodologies","investigate","metropolis","discusses","technical","approximation","performed","estimating","following","satisfaction","inconsistency","important","comparisons","properties","postulate","inconsistent","comparison","alternative","judgments","additional","numerical","reciprocal","asymptotically","frequentist","potentially","statistical","inference","comparable","stochastic","intuitive","sequences","synthetic","computation","classical","uhlenbeck","embedding","reduction","initially","supervised","satisfactory","approaches","primarily","intrinsic","classifiers","separation","generalization","structures","traditional","algorithms","interpolator","different","nonlinear","geometric","constructing","experimental","motivated","meanwhile","regularity","interpolation","dimensionality","extensions","embeddings","collections","lipschitz","significant","determine","characteristics","dependent","preferable","distributions","effective","successfully","multitask","auxiliary","conditions","successful","morphosyntactic","improvements","correlate","magnitude","asymptotic","typically","coordinate","calculate","approximate","alignment","advantage","algebraic","approximating","understood","formulate","implement","increased","rationality","interpretability","temporally","deliberation","increasingly","environment","objective","specified","biological","artificial","computationally","substantially","correlations","validated","structure","continuous","identifiable","experimentally","hierarchy","parsimonious","computational","multivariate","attribute","dependence","simplified","expensive","dimensional","generalizes","robustness","monotonically","optimizing","iteration","objectives","assignment","converges","implementations","membership","incorporating","selection","surrogate","iterative"],"y":[58,807,57,327,2,50,148,211,7,66,238,120,1,381,299,100,159,1,63,41,238,394,27,11,12,564,18,213,71,3,250,18,102,58,81,72,23,35,37,177,111,4,22,529,53,12,338,71,268,90,85,108,0,27,143,4,77,872,5,591,68,0,35,103,130,162,15,138,2,22,40,126,115,67,82,21,7,361,29,194,1,10,118,94,10,128,96,3,9,2,49,158,186,66,142,33,93,124,161,103,1,97,99,17,192,12,387,15,43,97,30,102,158,192,577,1,742,61,73,34,355,63,16,8,22,40,49,82,23,8,213,72,90,65,5,110,247,72,10,28,147,80,2,80,7,55,20,102,25,19,126,50,95,16,17,27,62,61,48,4,22,20,6,54,111,173,38,31,145,98,27,38,36,317,124,5,47,29,6,314,22,29,30,20,54,162,34,90,7,51,37,34,27,24,31,17,56,143,16,73],"type":"bar"},{"x":["naturally","algorithm","statistics","introduce","embarrassingly","requiring","practical","comp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4593,), (4593, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fine</span> <span style=''>grained</span> <span style='background-color:rgba(0, 255, 0, 0.48800000000000004);'>Discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>Localization</span> <span style=''>via</span> <span style=''>Saliency</span> <span style=''>guided</span> <span style=''>Faster</span> <span style=''>R</span> <span style=''>CNN</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.48800000000000004);'>Discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>localization</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5185185185185185);'>essential</span> <span style=''>for</span> <span style=''>fine</span> <span style=''>grained</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>task</span> <span style=''>which</span> <span style=''>devotes</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>recognizing</span> <span style=''>hundreds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>subcategories</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style=''>basic</span> <span style=''>level</span> <span style=''>category</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>Reflecting</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.48800000000000004);'>discriminative</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>among</span> <span style='background-color:rgba(0, 255, 0, 0.3074889867841409);'>different</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>subcategories</span> <span style=''>are</span> <span style=''>subtle</span> <span style=''>and</span> <span style=''>local</span> <span style=''>Existing</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>adopt</span> <span style=''>a</span> <span style=''>two</span> <span style=''>stage</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>The</span> <span style=''>first</span> <span style=''>stage</span> <span style=''>is</span> <span style=''>to</span> <span style=''>localize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.48800000000000004);'>discriminative</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>the</span> <span style=''>second</span> <span style=''>is</span> <span style=''>to</span> <span style=''>encode</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.48800000000000004);'>discriminative</span> <span style=''>features</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>However</span> <span style=''>these</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>have</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3457943925233645);'>limitations</span> <span style=''>(1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Separation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style=''>stage</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3214285714285715);'>consuming</span> <span style=''>(2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependence</span> <span style=''>on</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Minimax</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Bandable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style=''>Matrices</span> <br/><br/><span style=''>The</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>provides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style=''>insight</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>setting</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>normal</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>pattern</span> <span style=''>in</span> <span style=''>the</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>commonly</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gauss</span> <span style=''>Markov</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>encodes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statements</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Minimax</span> <span style=''>results</span> <span style=''>under</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>norm</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrices</span> <span style=''>both</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>banded</span> <span style=''>and</span> <span style=''>for</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>minimax</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>banded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.34883720930232553);'>Guarantees</span> <span style=''>of</span> <span style=''>Total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>for</span> <span style=''>Signal</span> <span style=''>Recovery</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>using</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>signals</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>have</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>support</span> <span style=''>from</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3925925925925926);'>establish</span> <span style=''>the</span> <span style=''>proof</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>of</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>(TV)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovering</span> <span style=''>emphone</span> <span style='background-color:rgba(255, 0, 0, 0.4033149171270718);'>dimensional</span> <span style=''>signal</span> <span style=''>with</span> <span style=''>sparse</span> <span style=''>gradient</span> <span style=''>support</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>answers</span> <span style=''>the</span> <span style=''>open</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>proving</span> <span style=''>the</span> <span style=''>fidelity</span> <span style=''>of</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>in</span> <span style=''>such</span> <span style=''>a</span> <span style=''>setting</span> <span style=''>citeTVMulti</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>recoverable</span> <span style=''>gradient</span> <span style=''>sparsity</span> <span style=''>can</span> <span style=''>grow</span> <span style=''>linearly</span> <span style=''>with</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.4106280193236715);'>dimension</span> <span style=''>when</span> <span style=''>TV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>is</span> <span style=''>used</span> <span style=''>Recoverable</span> <span style=''>sparsity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholds</span> <span style=''>of</span> <span style=''>TV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>computed</span> <span style=''>for</span> <span style=''>1</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>textual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>time</span> <span style=''>series</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prognostics</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Prognostics</span> <span style=''>or</span> <span style=''>early</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style=''>incipient</span> <span style=''>faults</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>industrial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>based</span> <span style=''>and</span> <span style=''>preventive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintenance</span> <span style=''>Physics</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>modeling</span> <span style=''>fault</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>progression</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>infeasible</span> <span style=''>due</span> <span style=''>to</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interacting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncontrolled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environmental</span> <span style=''>factors</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>Moreover</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prognostics</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>to</span> <span style=''>new</span> <span style=''>domains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Consequently</span> <span style=''>domain</span> <span style=''>agnostic</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prognostics</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>Damage</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>progression</span> <span style=''>is</span> <span style=''>a</span> <span style=''>path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>process</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>modeling</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>patterns</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>for</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>both</span> <span style=''>the</span> <span style=''>current</span> <span style=''>damage</span> <span style=''>state</span> <span style=''>and</span> <span style=''>its</span> <span style='background- ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.06812477590534241)
# 	experimental (0.1272857655073503)
# 	information (0.23126568662603084)
# 	segmentation (0.06704912154894227)
# 	processing (0.102545715310147)
# 	architecture (0.09465758336321262)
# 	different (0.2660451774829688)
# 	detection (0.13087128002868412)
# 	recognition (0.14091072068841878)
# 	convolutional (0.14126927214055218)
#
# Some Statistics words are:
# 	stochastic (0.12928891098955744)
# 	variables (0.13774241670810541)
# 	estimation (0.17105917454002983)
# 	algorithm (0.391347588264545)
# 	theoretical (0.16260566882148186)
# 	statistical (0.16210840377921432)
# 	distribution (0.1844853306812531)
# 	dimensional (0.1894579811039284)
# 	regression (0.1720537046245649)
# 	inference (0.20387866732968674)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2b154e1e-0495-43a2-9ba4-2bb43d501bd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b154e1e-0495-43a2-9ba4-2bb43d501bd6")) {                    Plotly.newPlot(                        "2b154e1e-0495-43a2-9ba4-2bb43d501bd6",                        [{"x":["naturally","algorithm","statistics","introduce","embarrassingly","requiring","practical","complexity","competitors","sufficient","parameters","parameter","parallelizes","efficient","available","procedure","challenge","regresses","likelihood","projection","prediction","convolutional","distortion","intrinsically","keypoints","framework","coordinates","estimation","invariant","regressing","outperforms","weaknesses","conventional","difficulty","perspective","estimates","phenomena","regularized","contributions","presented","component","exhibited","correspond","demonstrate","established","paradigms","optimization","interactions","particular","formulation","particularly","regression","unmeasured","principal","introduced","networked","relations","performance","justified","experiments","simulated","linearities","parametric","structured","variables","theoretical","methodologies","investigate","metropolis","discusses","technical","approximation","performed","estimating","following","satisfaction","inconsistency","important","comparisons","properties","postulate","inconsistent","comparison","alternative","judgments","additional","numerical","reciprocal","asymptotically","frequentist","potentially","statistical","inference","comparable","stochastic","intuitive","sequences","synthetic","computation","classical","uhlenbeck","embedding","reduction","initially","supervised","satisfactory","approaches","primarily","intrinsic","classifiers","separation","generalization","structures","traditional","algorithms","interpolator","different","nonlinear","geometric","constructing","experimental","motivated","meanwhile","regularity","interpolation","dimensionality","extensions","embeddings","collections","lipschitz","significant","determine","characteristics","dependent","preferable","distributions","effective","successfully","multitask","auxiliary","conditions","successful","morphosyntactic","improvements","correlate","magnitude","asymptotic","typically","coordinate","calculate","approximate","alignment","advantage","algebraic","approximating","understood","formulate","implement","increased","rationality","interpretability","temporally","deliberation","increasingly","environment","objective","specified","biological","artificial","computationally","substantially","correlations","validated","structure","continuous","identifiable","experimentally","hierarchy","parsimonious","computational","multivariate","attribute","dependence","simplified","expensive","dimensional","generalizes","robustness","monotonically","optimizing","iteration","objectives","assignment","converges","implementations","membership","incorporating","selection","surrogate","iterative","substitution","convergence","multiplications","eigenvector","guarantees","clustering","quadratic","extensive","effectiveness","aggregates","nonnegative","factorization","electricity","measurements","consumption","autocorrelation","relaxation","recovering","individual","furthermore","observations","quadratically","illustrate","constrained","classifier","preliminary","approximately","dermatologists","establishes","occurrence","regarding","techniques","implements","existence","solutions","countries","confirmed","introduces","literature","information","classification","population","dermatological","reproducing","unsupervised","contaminated","operators","covariance","influential","explicitly","visualization","principles","implicitly","effectively","in ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unmeasured
# 	linearities
# 	autocorrelation
# 	quadratically
# 	dermatological
# 	transports
# 	datapoints
# 	invariances
# 	differentiability
# 	diagonalise
# 	alternates
# 	explodingvanishing
# 	reconstructive
# 	randomforest
# 	blockmodels
# 	martingale
# 	prioritization
# 	penalization
# 	straggler
# 	replication
# Some words which never appear in Statistics papers:
# 	morphosyntactic
# 	deliberation
# 	worrisome
# 	commented
# 	tardiness
# 	occlusions
# 	templates
# 	abstractive
# 	inflection
# 	articulated
# 	vocabularies
# 	featureless
# 	laparoscope
# 	memristor
# 	memristors
# 	phenomenological
# 	workstations
# 	epidemiological
# 	apprehended
# 	transformer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0785333866945786e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
